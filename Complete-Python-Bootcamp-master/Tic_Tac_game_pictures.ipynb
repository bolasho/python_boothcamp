# %%
import IPython.display as dp
import IPython.core.display as ds
from IPython.display import display,Image
from IPython.core.display import HTML 
#PATH = r"C:\Users\bola\Pictures\i_python"
Nat=Image(filename = r"C:\Users\bola\Pictures\i_python\IMG_2213.JPG", width=50, height=50)
print("my name is nathan")
Nat
# Out:
# my name is nathan

# %%
import IPython.display as dp
from IPython.display import Image
from IPython.core.display import HTML 
PATH = r"C:\Users\bola\Pictures\i_python"
Nat=Image(filename =r"C:\Users\bola\Pictures\i_python\IMG_2213.JPG", width=50, height=50)
Nat

# %%
#PATH = r"C:\Users\bola\Pictures\i_python"
Bol=Image(filename =r"C:\Users\bola\Pictures\i_python\WIN_20160427_07_22_59_Pro.jpg", width=50, height=50)
Bol

# %%
X=Bol
O=Nat

inp=[]

inp.append(X)
inp.append(O)
display(inp)
# Out:
# [<IPython.core.display.Image object>, <IPython.core.display.Image object>]

# %%
import matplotlib.pyplot as plt
def displayImage(image):
    plt.imshow(image)
    plt.show()

# %%
from scipy import misc
# read this image in as a NumPy array, using imread from scipy.misc
M = misc.imread(inp)

M.shape       # imread imports as RGBA, so the last dimension is the alpha channel
    #array([258, 384, 4])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-81aa5479091d> in <module>()
#       1 from scipy import misc
#       2 # read this image in as a NumPy array, using imread from scipy.misc
# ----> 3 M = misc.imread(inp)
#       4
#       5 M.shape       # imread imports as RGBA, so the last dimension is the alpha channel
#
# C:\Users\bola\AppData\Local\Enthought\Canopy\User\lib\site-packages\scipy\misc\pilutil.pyc in imread(name, flatten, mode)
#     152     """
#     153
# --> 154     im = Image.open(name)
#     155     return fromimage(im, flatten=flatten, mode=mode)
#     156
#
# C:\Users\bola\AppData\Local\Enthought\Canopy\User\lib\site-packages\PIL\Image.pyc in open(fp, mode)
#    2275         fp.seek(0)
#    2276     except (AttributeError, io.UnsupportedOperation):
# -> 2277         fp = io.BytesIO(fp.read())
#    2278
#    2279     prefix = fp.read(16)
# ...

# %%
displayImage(inp)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-ad5d95b452de> in <module>()
# ----> 1 displayImage(inp)
#
# <ipython-input-64-a741f21d4e7a> in displayImage(image)
#       1 import matplotlib.pyplot as plt
#       2 def displayImage(image):
# ----> 3     plt.imshow(image)
#       4     plt.show()
#
# C:\Users\bola\AppData\Local\Enthought\Canopy\User\lib\site-packages\matplotlib\pyplot.pyc in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3020                         filternorm=filternorm, filterrad=filterrad,
#    3021                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3022                         **kwargs)
#    3023     finally:
#    3024         ax.hold(washold)
#
# ...

# %%
import numpy as np
x = np.random.choice(inp)
x

# %%
player_1= X or O
while player_1!= X or O:
    player_1=raw_input("please enter X or O ").upper()
    if player_1 == 'X': #or  player_1 =='O' :
        player_1 = X #or player_1=O
    elif player_1 == 'O':
        player_1 = O
        print("welcome")
        break
    else: 
        print("Sorry please choose Either 'X' or 'O'")
# Out:
# please enter X or O x
# please enter X or O o
# welcome

# %%
player_2= X or O

while player_2 !='X' or 'O':
    player_2=raw_input("please enter 'X' or 'O'").upper()
    if player_2 == player_1:
        print("Sorry player_1 already has that please choose that", player_2)
    elif player_2 != player_1 and player_2== 'X' or player_2=='O':
        player_2=X 
        player_2=O
        print("welcome")
        break
    else:
        print("Sorry please choose Either 'X' or 'O'")
# Out:
# please enter 'X' or 'O'x
# welcome

# %%
choicez=[]
choicez.append(player_1)
choicez.append(player_2)
choicez
# Out:
# [<IPython.core.display.Image object>, <IPython.core.display.Image object>]

# %%
import numpy as np
import matplotlib as plt
choices=choicez
T=np.random.choice(choices, 9, p=[0.5, 0.5])
T=T.reshape((3, 3))
#T
g=tuple(T)
#ds.display(g)
#dp.set_matplotlib_formats(T)
display(Image(T))

# %%
for image_path in g:  # images is a list of paths
    display(Image(image_path))

# %%
winning_comb= [   
             [T[0][0],T[1][1],T[2][2]],
             [T[0][1],T[1][1],T[2][1]],
             [T[0][2],T[1][1],T[2][0]],
             [T[0][0],T[1][0],T[2][0]],
             [T[0][2],T[1][2],T[2][2]],
             [T[1][0],T[1][1],T[1][2]]
               ]
count_1=0
count_2=0
for i in winning_comb:
    if i==[player_1] *3:
        count_1 +=1
    elif i==[player_2] *3:
        count_2=count_2 +1
#print(count_1)  
#print(count_2)
if count_1 > count_2:
    print("Player_1 is the winner and matches winning positions : {} times".format(count_1))
    print(T)
elif count_2 > count_1:
    print("Player_2 is the winner and matches winning positions : {} times".format(count_2))
    print(T)
else:
    print("Draw")
    print(T)
# Out:
# Player_1 is the winner and matches winning positions : 6 times
# [[<IPython.core.display.Image object> <IPython.core.display.Image object>
#   <IPython.core.display.Image object>]
#  [<IPython.core.display.Image object> <IPython.core.display.Image object>
#   <IPython.core.display.Image object>]
#  [<IPython.core.display.Image object> <IPython.core.display.Image object>
#   <IPython.core.display.Image object>]]
